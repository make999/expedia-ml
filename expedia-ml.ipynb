# %%
import pandas as pd

train = pd.read_csv("../input/train.csv")

# %%
#get data where is_booking==1
train = train[train.is_booking==1]

# %%
train.columns
# Out:
# Index([u'date_time', u'site_name', u'posa_continent', u'user_location_country',
#        u'user_location_region', u'user_location_city',
#        u'orig_destination_distance', u'user_id', u'is_mobile', u'is_package',
#        u'channel', u'srch_ci', u'srch_co', u'srch_adults_cnt',
#        u'srch_children_cnt', u'srch_rm_cnt', u'srch_destination_id',
#        u'srch_destination_type_id', u'is_booking', u'cnt', u'hotel_continent',
#        u'hotel_country', u'hotel_market', u'hotel_cluster'],
#       dtype='object')

# %%
train.shape
# Out:
# (3000693, 24)

# %%
train.to_csv('train_isb1.csv',sep=',', encoding='utf-8')

# %%
train = train.drop(['site_name','posa_continent','channel','srch_children_cnt','srch_adults_cnt','srch_rm_cnt','cnt','hotel_continent'], axis=1)

# %%
train.columns
# Out:
# Index([u'date_time', u'user_location_country', u'user_location_region',
#        u'user_location_city', u'orig_destination_distance', u'user_id',
#        u'is_mobile', u'is_package', u'srch_ci', u'srch_co',
#        u'srch_destination_id', u'srch_destination_type_id', u'is_booking',
#        u'hotel_country', u'hotel_market', u'hotel_cluster'],
#       dtype='object')

# %%
train = train.drop(['is_mobile'],axis=1)

# %%
train.dropna()
# Out:
#                     date_time  user_location_country  user_location_region  \
# 1         2014-08-11 08:22:12                     66                   348
# 79        2014-01-03 16:30:17                     66                   462
# 81        2014-01-03 16:44:56                     66                   462
# 83        2014-01-03 17:11:36                     66                   462
# 128       2014-10-29 14:32:19                     66                   174
# 133       2014-12-05 09:58:15                     66                   174
# 372       2014-04-19 09:44:32                     66                   174
# 401       2014-10-18 18:35:06                     66                   174
# 408       2013-11-09 07:45:52                     66                   189
# 410       2013-11-09 07:48:54                     66                   189
# 414       2014-05-10 10:17:00                     66                   189
# ...

# %%
train.drop(['is_booking'],axis=1)
# Out:
#                     date_time  user_location_country  user_location_region  \
# 1         2014-08-11 08:22:12                     66                   348
# 79        2014-01-03 16:30:17                     66                   462
# 81        2014-01-03 16:44:56                     66                   462
# 83        2014-01-03 17:11:36                     66                   462
# 128       2014-10-29 14:32:19                     66                   174
# 133       2014-12-05 09:58:15                     66                   174
# 372       2014-04-19 09:44:32                     66                   174
# 401       2014-10-18 18:35:06                     66                   174
# 408       2013-11-09 07:45:52                     66                   189
# 410       2013-11-09 07:48:54                     66                   189
# 414       2014-05-10 10:17:00                     66                   189
# ...

# %%
train.dropna()
# Out:
#                     date_time  user_location_country  user_location_region  \
# 1         2014-08-11 08:22:12                     66                   348
# 79        2014-01-03 16:30:17                     66                   462
# 81        2014-01-03 16:44:56                     66                   462
# 83        2014-01-03 17:11:36                     66                   462
# 128       2014-10-29 14:32:19                     66                   174
# 133       2014-12-05 09:58:15                     66                   174
# 372       2014-04-19 09:44:32                     66                   174
# 401       2014-10-18 18:35:06                     66                   174
# 408       2013-11-09 07:45:52                     66                   189
# 410       2013-11-09 07:48:54                     66                   189
# 414       2014-05-10 10:17:00                     66                   189
# ...

# %%
train.shape
# Out:
# (1985514, 15)

# %%
train.columns
# Out:
# Index([u'date_time', u'user_location_country', u'user_location_region',
#        u'user_location_city', u'orig_destination_distance', u'user_id',
#        u'is_package', u'srch_ci', u'srch_co', u'srch_destination_id',
#        u'srch_destination_type_id', u'is_booking', u'hotel_country',
#        u'hotel_market', u'hotel_cluster'],
#       dtype='object')
